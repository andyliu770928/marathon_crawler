# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSoup 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")
# print(r.text)
df = pd.DataFrame(columns=['作者', '標題','時間'])
i=0
for d in soup.find_all(class_="title"):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        data=r.find_all(class_='article-meta-value')
        df.loc[i] = [data[0].text, data[2].text, data[3].text]
        i+=1
    except:
        continue
    
df.iloc[0]
# Out:
# 作者           NSYSUheng (Madara)
# 標題    [情報] AD今天29投20中，狂砍賽季新高50分
# 時間     Mon Dec  9 13:06:54 2019
# Name: 0, dtype: object

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
df
# Out:
#                             作者                                      標題  \
# 0           NSYSUheng (Madara)               [情報] AD今天29投20中，狂砍賽季新高50分
# 1      cute320518 (cute320518)                [新聞] 向吉喆默哀 中國球迷素質讓林書豪動怒了
# 2            thnlkj0665 (灰色地帶)              [花邊] 笑稱跳投不如兒子 詹皇:我在家中只能排第三
# 3             MayBeSoft (小小瑜兒)         [花邊] Vogel: AD的表現是old-school風格的
# 4            LinBaoYan (負酬者聯盟)                [新聞] 戴維斯狂飆50分 湖人退灰狼笑納4連勝
# 5              Angel0724 (ND5)               [新聞] 致勝上籃後沒跟KD擊掌 丁丁：真不好意思
# 6               pneumo (超☆冒險蓋)                [情報] CP3對於OKC上半場兩次延誤比賽被吹
# 7                   Vedan (味丹)                      [公告] 樂透取消及未來不再開啟樂透
# 8   qazwsx879345 (Rajon Rondo)                           [公告] 版主上任相關事項
# 9               JerroLi (銀色小刀)  [情報] SEASON Schedule 賽程 December 19–20
# 10         dragon803 (好想去露營啊~)          [公告]是否禁止basketball top 5文章投票開始
#
#                           時間
# 0   Mon Dec  9 13:06:54 2019
# 1   Mon Dec  9 13:35:38 2019
# 2   Mon Dec  9 13:52:22 2019
# 3   Mon Dec  9 14:00:54 2019
# 4   Mon Dec  9 14:02:29 2019
# 5   Mon Dec  9 14:43:34 2019
# 6   Mon Dec  9 15:39:12 2019
# 7   Mon Jun 24 15:08:02 2019
# 8   Fri Oct 25 10:44:03 2019
# 9   Fri Nov 29 00:46:01 2019
# 10  Sun Dec  8 23:55:00 2019

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
r = requests.get(url, cookies={'over18': '1'})

soup = BeautifulSoup(r.text, "html5lib")
# print(r.text)
df = pd.DataFrame(columns=['作者', '標題','時間'])
i=0
for d in soup.find_all(class_="title"):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href'], cookies={'over18': '1'}).text, "html5lib")
        data=r.find_all(class_='article-meta-value')
        df.loc[i] = [data[0].text, data[2].text, data[3].text]
        i+=1
    except:
        continue
    
df
# Out:
#                             作者                              標題  \
# 0      Justapig (就只是一隻豬我心領了的 )              [問卦] 支持國民黨的甲甲是不是智障
# 1             miler22020 (orz)  Re: [新聞] 美麗島電子報不分區民調:綠18席藍10席民
# 2   chinaeatshit (我愛台灣！中國吃屎！！)               [問卦] 劉備當年為什麼不重用陳群
# 3            mark32928 (國片小王子)            [問卦] 為什麼貝莉梅40歲還可以這麼正
# 4                vi000246 (Vi)             [問卦] 有沒有青年就業旗艦計畫的八卦
# 5      PeterHenson (尋找布宜諾斯艾利斯)        Re: [問卦] 臺灣是不是低下階層才不吃牛肉？
# 6              ddiicckk (Life)            [爆卦] 有沒有發票對中卻沒法領的八卦?
# 7         a000000000 (中野零nine)          Re: [問卦] 八卦版的香港風向怎麼變惹?
# 8                 bybus (好久不見)       Re: [問卦] 鄉民願不願意大量開放香港人來台?
# 9             kuso2005 (一時想不到)           [新聞] 蔡英文：我們一起繼續撐香港的自由
# 10            cutbear123 (皇帝熊)  Re: [新聞] 美麗島電子報不分區民調:綠18席藍10席民
# 11           arsonlolita (蘿莉塔)          [公告] 八卦板板規(2019.08.21)
# 12            arsonlolita (板主)                   [公告] 宣導禁止回文政問
# 13                   witty ( )     [協尋] 11/20高市大順一路548號順明街行車記錄
# 14               Amybook (123)          協尋12/6台中市向上路往精科五路行車記錄器
# 15              Bignana (天劍煙雨)              [公告] 一劍無悔，十二月置底閒聊文
#
#                           時間
# 0   Mon Dec  9 16:05:24 2019
# 1   Mon Dec  9 16:05:32 2019
# 2   Mon Dec  9 16:05:56 2019
# 3   Mon Dec  9 16:07:26 2019
# 4   Mon Dec  9 16:09:25 2019
# 5   Mon Dec  9 16:09:40 2019
# 6   Mon Dec  9 16:09:35 2019
# 7   Mon Dec  9 16:10:12 2019
# 8   Mon Dec  9 16:10:13 2019
# 9   Mon Dec  9 16:10:28 2019
# 10  Mon Dec  9 16:11:11 2019
# 11  Wed Aug 21 08:33:39 2019
# 12  Wed Nov 20 09:14:42 2019
# 13  Sun Nov 24 21:28:01 2019
# 14  Sun Dec  8 01:29:53 2019
# 15  Mon Dec  2 23:13:15 2019
