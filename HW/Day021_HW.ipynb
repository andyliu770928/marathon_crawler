# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例：
#
# 1. 取出今天所有的新聞
# 2. 取出現在時間兩小時內的新聞
# 3. 根據範例，取出三天前下午三點到五點的新聞

# %% [markdown]
# ## 1. 取出今天所有的新聞

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import datetime
# 打開瀏覽器
browser = webdriver.Chrome(executable_path='../chromedriver')
browser.get("https://www.ettoday.net/news/news-list.htm")

# 每個兩秒鐘自動往下滑
import time
for i in range(2):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
# 取得資料，丟到 BeautifulSoup 解析
html_source = browser.page_source
soup = BeautifulSoup(html_source, "html5lib")
print(datetime.datetime.now())
for d in soup.find(class_="part_list_2").find_all('h3'):
    if '2019/12/26' in d.find(class_="date").text:
        print(d.find(class_="date").text, d.find_all('a')[-1].text)

# 關閉瀏覽器
browser.quit();
# Out:
# 2019-12-26 01:06:19.331803
# 2019/12/26 00:59 「巨大三寶」國道秀神技術　他目擊崩潰：做夢喔！千人敲碗求結局
# 2019/12/26 00:58 小玉自爆「我是雙性戀」　親口認：我交過一個男朋友！
# 2019/12/26 00:51 台南女潟湖驚見「趴躺浮屍」！細看傻眼　網：要穿吉利服啦
# 2019/12/26 00:50 清水服務區大改造！日本「超強美食街」壽司、新宿咖哩飯進駐　1/18開幕內裝曝光
# 2019/12/26 00:49 一戀愛就鬼遮眼的星座TOP 3　第一名直接退化到小孩狀態
# 2019/12/26 00:43 木村拓哉做過23份工作！超狂履歷曝光　「每次都不超過3個月」自嘲：日本之恥
# 2019/12/26 00:40 豪哥麻吉談毒藥合約「有腦袋都會接受」　帕森斯：很想打球但非我能控制
# 2019/12/26 00:17 22歲嘻哈歌手「爬上車頂撒鈔票雨」！　民眾包圍瘋搶…他拍下PO網：給予的季節
# 2019/12/26 00:15 用60盎司戰斧牛排迎賓　晶華ROBIN’S牛排館12/25重新開幕
# 2019/12/26 00:10 學者眼／韓國瑜打到民進黨痛點　蔡英文提馬王政爭「缺乏領導人格局」
# 2019/12/26 00:08 陳菊人馬主導罷韓！　韓國瑜嘆：居然還提倡罷免柯文哲
# 2019/12/26 00:06 王浩宇指三大關鍵：無法排除「韓國瑜當選可能」　網：投票就對了
# 2019/12/26 00:06 陳文成案找不到「原始錄音帶」　國安局︰檔案要滿50年後才能開放
# 2019/12/26 00:05 ECFA將終止？韓國瑜尷尬打臉馬英九　政委酸：證明成效不如當初宣示的好
# 2019/12/26 00:03 哪個國家危害台灣安全？韓國瑜拒答「國名」　網友怒了：佛地魔？
# 2019/12/26 00:01 阿嬤味道回來了！「明星花露水」確定2020元旦後復出　總經理回應笑開了
# 2019/12/26 00:01 政見會全文／辣台妹再撿槍嗆爆韓國瑜！蔡英文經濟、能源、司改政見完整看
# 2019/12/26 00:00 服務再提昇！桃園機場第一航廈成功建置行李自動分揀系統

# %%
datetime.datetime.strftime(end_time,'%Y/%m/%d %H:%M')
# Out:
# '2019/12/25 23:11'

# %% [markdown]
# ## 2. 取出現在時間兩小時內的新聞

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import datetime
# 打開瀏覽器
browser = webdriver.Chrome(executable_path='../chromedriver')
browser.get("https://www.ettoday.net/news/news-list.htm")

# 每個兩秒鐘自動往下滑
import time
for i in range(2):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
# 取得資料，丟到 BeautifulSoup 解析
html_source = browser.page_source
soup = BeautifulSoup(html_source, "html5lib")
end_time = datetime.datetime.now()-datetime.timedelta(hours=2)
end_time_str = datetime.datetime.strftime(end_time,'%Y/%m/%d %H:%M')
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="date").text > end_time_str:
        print(d.find(class_="date").text, d.find_all('a')[-1].text)

# 關閉瀏覽器
browser.quit();
# Out:
# 2019/12/26 01:13 向佐郭碧婷甜慶1周年！　玫瑰花海超狂「兩人嘟嘴長一樣」網：越來越有夫妻臉
# 2019/12/26 00:59 「巨大三寶」國道秀神技術　他目擊崩潰：做夢喔！千人敲碗求結局
# 2019/12/26 00:58 小玉自爆「我是雙性戀」　親口認：我交過一個男朋友！
# 2019/12/26 00:51 台南女潟湖驚見「趴躺浮屍」！細看傻眼　網：要穿吉利服啦
# 2019/12/26 00:50 清水服務區大改造！日本「超強美食街」壽司、新宿咖哩飯進駐　1/18開幕內裝曝光
# 2019/12/26 00:49 一戀愛就鬼遮眼的星座TOP 3　第一名直接退化到小孩狀態
# 2019/12/26 00:43 木村拓哉做過23份工作！超狂履歷曝光　「每次都不超過3個月」自嘲：日本之恥
# 2019/12/26 00:40 豪哥麻吉談毒藥合約「有腦袋都會接受」　帕森斯：很想打球但非我能控制
# 2019/12/26 00:17 22歲嘻哈歌手「爬上車頂撒鈔票雨」！　民眾包圍瘋搶…他拍下PO網：給予的季節
# 2019/12/26 00:15 用60盎司戰斧牛排迎賓　晶華ROBIN’S牛排館12/25重新開幕
# 2019/12/26 00:10 學者眼／韓國瑜打到民進黨痛點　蔡英文提馬王政爭「缺乏領導人格局」
# 2019/12/26 00:08 陳菊人馬主導罷韓！　韓國瑜嘆：居然還提倡罷免柯文哲
# 2019/12/26 00:06 王浩宇指三大關鍵：無法排除「韓國瑜當選可能」　網：投票就對了
# 2019/12/26 00:06 陳文成案找不到「原始錄音帶」　國安局︰檔案要滿50年後才能開放
# 2019/12/26 00:05 ECFA將終止？韓國瑜尷尬打臉馬英九　政委酸：證明成效不如當初宣示的好
# 2019/12/26 00:03 哪個國家危害台灣安全？韓國瑜拒答「國名」　網友怒了：佛地魔？
# 2019/12/26 00:01 阿嬤味道回來了！「明星花露水」確定2020元旦後復出　總經理回應笑開了
# 2019/12/26 00:01 政見會全文／辣台妹再撿槍嗆爆韓國瑜！蔡英文經濟、能源、司改政見完整看
# 2019/12/26 00:00 服務再提昇！桃園機場第一航廈成功建置行李自動分揀系統
# ...

# %% [markdown]
# ## 3. 根據範例，取出三天前下午三點到五點的新聞

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import datetime
# 打開瀏覽器
browser = webdriver.Chrome(executable_path='../chromedriver')
browser.get("https://www.ettoday.net/news/news-list-2019-12-23-0.htm")

# 每個兩秒鐘自動往下滑
import time
for i in range(40):
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight),2000;")
    
    
# 取得資料，丟到 BeautifulSoup 解析
html_source = browser.page_source
soup = BeautifulSoup(html_source, "html5lib")
start_time_str = '2019/12/23 15:00'
end_time_str = '2019/12/23 17:00'
for d in soup.find(class_="part_list_2").find_all('h3'):
    if d.find(class_="date").text < start_time_str:
        break
    if d.find(class_="date").text <= end_time_str:
        print(d.find(class_="date").text, d.find_all('a')[-1].text)

# 關閉瀏覽器
browser.quit();
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-25-b27cb27a9d70> in <module>
#      10 for i in range(50):
#      11     time.sleep(2)
# ---> 12     browser.execute_script("window.scrollTo(0, document.body.scrollHeight),2000;")
#      13
#      14
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...
